# %% [raw]
# ---
# title: "Dataset of the Week #1: The Weather in Philadelphia"
# author: Kenadi
# date: 1/28/2026
# categories:
#     - DOW
#     - weather
# ---

# %% [markdown]
# ### My post

# %%
print('This is some code')
# Out:
# This is some code
