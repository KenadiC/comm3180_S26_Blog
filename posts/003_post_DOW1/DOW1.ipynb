# %% [raw]
# ---
# title: "Dataset of the Week #1: The Weather in Philadelphia"
# author: Kenadi
# date: 1/28/2026
# categories:
#     - DOW
#     - weather
# ---

# %% [markdown]
# ### My Post

# %%
print('This is some code')
# Out:
# This is some code

# %% [markdown]
# ---
#
# The Next Section
#
# ![](Phillyweathermeme.jpg){width=200}
#
# ---
#
# And another
#
# ---
